# %% [markdown]
# ## Web Scraping Amazon Best Sellers using BeautifulSoup
#
# Web scraping is a valuable skill to have in your data science toolkit. It can be used for a variety of purposes such as data collection for training machine learning models, or to collect data for analysis. In this tutorial, we will be using web scraping to collect data from Amazon's Best Sellers page. We will be using the BeautifulSoup library to scrape the data.
#
# Additionally, we will perform some basic data preprocessing which is an immediate activity after scraping.

# %%
## load libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re
import time
from datetime import datetime
import matplotlib.dates as mdates
import matplotlib.ticker as ticker
from urllib.request import urlopen
from bs4 import BeautifulSoup
import requests

# %%
## get the following data for the amazon best sellers

## name, url, category, rank, rating, number of reviews, price, date of scraping

url = 'https://www.amazon.in/gp/bestsellers/books/ref=zg_bs_pg_1?ie=UTF8&pg=1'

## get the html
html = requests.get(url)

## parse the html
soup = BeautifulSoup(html.content, 'html.parser')

## create a list of all the books
books = soup.find_all('div', id='gridItemRoot')

# %% [markdown]
# We will be scraping the following information from the Amazon Best Sellers page:
#
# >- Title
# >- Author
# >- Rating
# >- Number of reviews
# >- Price
# >- Link to the book's page

# %%
## name
title = books[0].find('div', class_="_cDEzb_p13n-sc-css-line-clamp-1_1Fn1y").text
author = books[0].find('a', class_="a-size-small a-link-child").find('div', class_="_cDEzb_p13n-sc-css-line-clamp-1_1Fn1y").text
rating = books[0].find('span', class_="a-icon-alt").text
reviews = books[0].find('span', class_="a-size-small").text.replace(',', '')
price = books[0].find('span', attrs={'class':'p13n-sc-price'}).text[1:] ## remove the rupee symbol
## get book link
link_to_book = books[0].find('a', class_="a-link-normal")['href']

## create the absolute link
base_url = 'https://www.amazon.in'
book_link = base_url + link_to_book

date = datetime.now().strftime("%Y-%m-%d %H:%M:%S")

# %%
## create a dataframe

## dictionary
df_dict = {'title':title, 'author':author, 'rating':rating, 'reviews':reviews, 'price':price, 'book_link': book_link, 'date':date}


df=pd.DataFrame(df_dict, index=[0])
df
# Out:
#                                                title       author  \
# 0  Atomic Habits: the life-changing million-copy ...  James Clear
#
#                rating reviews   price  \
# 0  4.6 out of 5 stars   78722  396.00
#
#                                            book_link                 date
# 0  https://www.amazon.in/Atomic-Habits-James-Clea...  2023-06-12 10:43:06

# %%
## extract data from the first page

book_title = []
book_author = []
book_rating = []
book_reviews = []
book_price = []
date_scraped = []
book_link = []

## make this a function

def get_best_sellers_books(container):

    for book in container:
        try:
            title = book.find('div', class_="_cDEzb_p13n-sc-css-line-clamp-1_1Fn1y").text
            book_title.append(title)
        except:
            book_title.append(np.nan)
        try:
            author = book.find('a', class_="a-size-small a-link-child").find('div', \
                attrs={'class': ("_cDEzb_p13n-sc-css-line-clamp-1_1Fn1y", \
                    "_cDEzb_p13n-sc-css-line-clamp-2_EWgCb")}).text
            book_author.append(author)
        except:
            book_author.append(np.nan)
        try:
            rating = book.find('span', class_="a-icon-alt").text
            book_rating.append(rating)
        except:
            book_rating.append(np.nan)
        try:
            reviews = book.find('span', class_="a-size-small").text.replace(',', '')
            book_reviews.append(reviews)
        except:
            book_reviews.append(np.nan)
        
        try:
            price = book.find('span', attrs={'class':'p13n-sc-price'}).text[1:].replace(',', '') ## remove the rupee symbol
            book_price.append(price)
        except:
            book_price.append(np.nan)

        link_to_book = book.find('a', class_="a-link-normal")['href']
        link = base_url + link_to_book
        book_link.append(link)


        date = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
        date_scraped.append(date)
    
    ## create a dictionary
    df_dict = {'title':book_title, 'author':book_author, 'rating':book_rating, \
        'reviews':book_reviews, 'price':book_price, 'book_link': book_link, 'date':date_scraped}
    
    ## create a dataframe
    best_sellers_books = pd.DataFrame(df_dict)
    
    return best_sellers_books

# %%
## get the data from the first page
best_sellers_books_pg1 = get_best_sellers_books(books)
best_sellers_books_pg1
# Out:
#                                                 title  \
# 0   Atomic Habits: the life-changing million-copy ...
# 1   The Hidden Hindu (Hindi Translation of The Hid...
# 2   Ikigai: The Japanese secret to a long and happ...
# 3                             The Psychology of Money
# 4   The Hidden Hindu: Science-Fiction meets Indian...
# 5   My First Library: Boxset of 10 Board Books for...
# 6   Grandma's Bag of Stories: Collection of 20+ Il...
# 7            Rich Dad Poor Dad: 25th Anniversary Edit
# 8                 The Power of Your Subconscious Mind
# 9                 Indian Polity Sixth Revised Edition
# 10  Brain Activity Book for Kids - 200+ Activities...
# 11                    Shrimad Bhagwat Geeta Yatharoop
# 12  My First Mythology Tale (Illustrated) (Set of ...
# 13  BlackBook of English Vocabulary March 2023 by ...
# 14  Energize Your Mind: Learn the Art of Mastering...
# 15  Oxford Student Atlas for India, Fourth Edition...
# 16  Do It Today: Overcome procrastination, improve...
# 17  World’s Greatest Books For Personal Growth & W...
# 18  MTG Objective NCERT at your FINGERTIPS Biology...
# 19                                 The Silent Patient
# 20  Oswaal CBSE Class 10 Science Question Bank (20...
# 21  My First Book of Pencil Control : Practice Pat...
# 22  Concept of Physics by H.C Verma Part - I - Ses...
# 23      Word Power Made Easy [Paperback] Norman Lewis
# 24                 Don't Believe Everything You Think
# 25                     The Magic Of The Lost Temple**
# 26  2023 - Edition - Lucent's General Knowledge - ...
# 27  Arihant All In One Class 10th Social Science f...
# 28  Little Colouring Books for Kids (Set of 10 Boo...
# 29                            The Hidden Hindu Book 3
# 30                        Hidden Hindu, The ( Book 2)
# 31                                                NaN
# 32                                            You Can
# 33            How to Win Friends and Influence People
# 34  Moral Story Books for Kids (Set of 10 Books) (...
# 35  108 Panchatantra Stories for Children (Illustr...
# 36                                      The Alchemist
# 37                               THE 48 LAWS OF POWER
# 38  Arihant All In One Class 10th English Language...
# 39                                The Compound Effect
# 40                               India that is Bharat
# 41            Dr Cuterus: Everything Nobody Tells You
# 42  Oswaal CBSE Class 10 Social Science Question B...
# 43  Quantitative Aptitude for Competitive Examinat...
# 44                The Power of Your Subconscious Mind
# 45  First Aid for the USMLE Step 1 2023, Thirty Th...
# 46  The Almanack Of Naval Ravikant: A Guide to Wea...
# 47  Arihant All In One Class 10th Science for CBSE...
# 48  Think Straight: Change your thoughts, Change y...
# 49      Think and Grow Rich: THE 21st CENTURY EDITION
#
#                                   author              rating  \
# 0                            James Clear  4.6 out of 5 stars
# 1                           Akshat Gupta  4.5 out of 5 stars
# 2                      Francesc Miralles  4.6 out of 5 stars
# 3                          Morgan Housel  4.6 out of 5 stars
# 4                           Akshat Gupta  4.4 out of 5 stars
# 5                     Wonder House Books  4.5 out of 5 stars
# 6                                    NaN  4.6 out of 5 stars
# 7                     Robert T. Kiyosaki  4.5 out of 5 stars
# 8                          Joseph Murphy  4.5 out of 5 stars
# 9                           M Laxmikanth  4.5 out of 5 stars
# 10                           Maple Press  4.5 out of 5 stars
# 11  A.C. Bhaktivendanta Swami Prabhupada  4.8 out of 5 stars
# 12                           Maple Press  4.4 out of 5 stars
# 13                                   NaN  4.4 out of 5 stars
# 14                        Gaur Gopal Das  4.6 out of 5 stars
# 15                                   NaN  4.6 out of 5 stars
# 16                         Darius Foroux  4.4 out of 5 stars
# 17                                   NaN  4.5 out of 5 stars
# 18                   MTG Editorial Board  4.4 out of 5 stars
# 19                      Alex Michaelides  4.5 out of 5 stars
# 20                Oswaal Editorial Board  4.4 out of 5 stars
# 21                    Wonder House Books  4.4 out of 5 stars
# 22                            H.C. Verma  4.6 out of 5 stars
# 23                          Norman Lewis  4.4 out of 5 stars
# 24                         Joseph Nguyen  4.6 out of 5 stars
# 25                                   NaN  4.6 out of 5 stars
# 26                                   NaN  4.2 out of 5 stars
# 27                                   NaN  3.9 out of 5 stars
# 28                           Maple Press  4.3 out of 5 stars
# 29                          Akshat Gupta  4.6 out of 5 stars
# 30                          Akshat Gupta  4.6 out of 5 stars
# 31                                   NaN  4.1 out of 5 stars
# 32                  George Matthew Adams  4.3 out of 5 stars
# 33                         Dale Carnegie  4.5 out of 5 stars
# 34                           Maple Press  4.5 out of 5 stars
# 35                           Maple Press  4.4 out of 5 stars
# 36                          Paulo Coelho  4.6 out of 5 stars
# 37                         Robert Greene  4.6 out of 5 stars
# 38                                   NaN  4.1 out of 5 stars
# 39                                   NaN  4.6 out of 5 stars
# 40                          J Sai Deepak  4.8 out of 5 stars
# 41                    Dr Tanaya Narendra  4.7 out of 5 stars
# 42                Oswaal Editorial Board  4.5 out of 5 stars
# 43                         R. S Aggarwal  4.3 out of 5 stars
# 44                         Joseph Murphy  4.5 out of 5 stars
# 45                                   NaN  4.3 out of 5 stars
# 46                        Eric Jorgenson  4.6 out of 5 stars
# 47                                   NaN  4.0 out of 5 stars
# 48                         Darius Foroux  4.2 out of 5 stars
# 49                         Napoleon Hill  4.5 out of 5 stars
#
#                                               reviews    price  \
# 0                                               78722   396.00
# 1                                                 302   150.00
# 2                                               48160   374.00
# 3                                               50257   200.00
# 4                                                1535   180.00
# 5                                               69946   399.00
# 6                                         Sudha Murty   157.00
# 7                                               22486   369.00
# 8                                               74628   115.00
# 9                                                4497   650.00
# 10                                               3530    85.00
# 11                                              16053   193.50
# 12                                               7062   179.00
# 13                                    Nikhil Kr Gupta   250.00
# 14                                               1740   160.00
# 15                            Oxford University Press   173.00
# 16                                               6599   127.00
# 17                                      Dale Carnegie   299.00
# 18                                                132   639.00
# 19                                             255105   203.00
# 20                                               1106   425.00
# 21                                              24500    89.00
# 22                                              13031   330.00
# 23                                              46549    98.00
# 24                                                376   194.00
# 25                                        Sudha Murty   165.00
# 26                                    Dr. Binay Karna   214.00
# 27                           Farah Sultan Aditya Raj    330.00
# 28                                               2652   195.00
# 29                                                251   206.00
# 30                                                585   188.00
# 31                                               2399   200.00
# 32                                               3510    99.00
# 33                                             113611    99.00
# 34                                               1349   245.00
# 35                                               3289   128.00
# 36                                             137198   264.00
# 37                                              16250   599.00
# 38                   Vaishali Jaiwal Srishti Agarwal    359.00
# 39                                       Darren Hardy   154.00
# 40                                               5946   449.00
# 41                                                267   179.00
# 42                                                 96   433.00
# 43                                               1254   499.00
# 44                                              74628   105.00
# 45                                     Matthew Sochat  1010.00
# 46                                              14222   209.00
# 47  Sanubia & Rashmi Gupta Sonal Singh & Ruchi Kap...   382.00
# 48                                              11494   127.00
# 49                                               4475    99.00
#
#                                             book_link                 date
# 0   https://www.amazon.in/Atomic-Habits-James-Clea...  2023-06-12 11:05:09
# 1   https://www.amazon.in/Hidden-Hindu-Hindi-Trans...  2023-06-12 11:05:09
# 2   https://www.amazon.in/Ikigai-H%C3%A9ctor-Garc%...  2023-06-12 11:05:09
# 3   https://www.amazon.in/Psychology-Money-Morgan-...  2023-06-12 11:05:09
# 4   https://www.amazon.in/Hidden-Hindu-Akshat-Gupt...  2023-06-12 11:05:09
# 5   https://www.amazon.in/My-First-Library-Boxset-...  2023-06-12 11:05:09
# 6   https://www.amazon.in/Grandmas-Bag-Stories-Sud...  2023-06-12 11:05:09
# 7   https://www.amazon.in/Rich-Dad-Poor-Middle-Ann...  2023-06-12 11:05:09
# 8   https://www.amazon.in/Power-Your-Subconscious-...  2023-06-12 11:05:09
# 9   https://www.amazon.in/Indian-English-Revised-S...  2023-06-12 11:05:09
# 10  https://www.amazon.in/Brain-Activity-Book-Kids...  2023-06-12 11:05:09
# 11  https://www.amazon.in/Bhagavad-Gita-Bhaktivend...  2023-06-12 11:05:09
# 12  https://www.amazon.in/First-Mythology-Tale-Ill...  2023-06-12 11:05:09
# 13  https://www.amazon.in/BlackBook-English-Vocabu...  2023-06-12 11:05:09
# 14  https://www.amazon.in/Energize-Your-Mind-Maste...  2023-06-12 11:05:09
# 15  https://www.amazon.in/Oxford-Student-Atlas-Ind...  2023-06-12 11:05:09
# 16  https://www.amazon.in/Do-Today-procrastination...  2023-06-12 11:05:09
# 17  https://www.amazon.in/Worlds-Greatest-Personal...  2023-06-12 11:05:09
# 18  https://www.amazon.in/Objective-NCERT-your-FIN...  2023-06-12 11:05:09
# 19  https://www.amazon.in/Silent-Patient-Alex-Mich...  2023-06-12 11:05:09
# 20  https://www.amazon.in/Oswaal-CBSE-Class-Scienc...  2023-06-12 11:05:09
# 21  https://www.amazon.in/First-Book-Patterns-Penc...  2023-06-12 11:05:09
# 22  https://www.amazon.in/Concept-Physics-Part-1-2...  2023-06-12 11:05:09
# 23  https://www.amazon.in/Word-Power-Made-Norman-L...  2023-06-12 11:05:09
# 24  https://www.amazon.in/Dont-Believe-Everything-...  2023-06-12 11:05:09
# 25  https://www.amazon.in/Magic-Lost-Temple-Sudha-...  2023-06-12 11:05:09
# 26  https://www.amazon.in/2023-Lucents-General-Kno...  2023-06-12 11:05:09
# 27  https://www.amazon.in/Arihant-Class-Social-Sci...  2023-06-12 11:05:09
# 28  https://www.amazon.in/Colouring-Books-Set-10/d...  2023-06-12 11:05:09
# 29  https://www.amazon.in/Hidden-Hindu-Book-3/dp/0...  2023-06-12 11:05:09
# 30  https://www.amazon.in/Hidden-Hindu-2-Akshat-Gu...  2023-06-12 11:05:09
# 31  https://www.amazon.in/Trading-Breakout-Pattern...  2023-06-12 11:05:09
# 32  https://www.amazon.in/You-Can-George-Matthew-A...  2023-06-12 11:05:09
# 33  https://www.amazon.in/How-Win-Friends-Influenc...  2023-06-12 11:05:09
# 34  https://www.amazon.in/Moral-Story-Books-Kids-S...  2023-06-12 11:05:09
# 35  https://www.amazon.in/108-Panchatantra-Stories...  2023-06-12 11:05:09
# 36  https://www.amazon.in/Alchemist-Paulo-Coelho/d...  2023-06-12 11:05:09
# 37  https://www.amazon.in/Laws-Power-Robert-Greene...  2023-06-12 11:05:09
# 38  https://www.amazon.in/Arihant-English-Language...  2023-06-12 11:05:09
# 39  https://www.amazon.in/Compound-Effect-Darren-H...  2023-06-12 11:05:09
# 40  https://www.amazon.in/India-that-Bharat-Civili...  2023-06-12 11:05:09
# 41  https://www.amazon.in/Dr-Cuterus-Everything-No...  2023-06-12 11:05:09
# 42  https://www.amazon.in/Oswaal-Class-Social-Scie...  2023-06-12 11:05:09
# 43  https://www.amazon.in/Quantitative-Aptitude-Co...  2023-06-12 11:05:09
# 44  https://www.amazon.in/Power-Your-Subconscious-...  2023-06-12 11:05:09
# 45  https://www.amazon.in/First-USMLE-Step-Thirty-...  2023-06-12 11:05:09
# 46  https://www.amazon.in/Almanack-Naval-Ravikant-...  2023-06-12 11:05:09
# 47  https://www.amazon.in/Arihant-Class-10th-Scien...  2023-06-12 11:05:09
# 48  https://www.amazon.in/Think-Straight-Change-yo...  2023-06-12 11:05:09
# 49  https://www.amazon.in/Think-Grow-Rich-21st-CEN...  2023-06-12 11:05:09

# %%
## get data from the remaining pages

## There is only one additional page
## get the url for the next page
pg2_url = 'https://www.amazon.in/gp/bestsellers/books/ref=zg_bs_pg_2?ie=UTF8&pg=2'

## get the html
html2 = requests.get(pg2_url)

## parse the html
soup2 = BeautifulSoup(html2.content, 'html.parser')

## container
books2 = soup2.find_all('div', id='gridItemRoot')

## get the data from the other pages
best_sellers_books_all = get_best_sellers_books(books2)
best_sellers_books_all
# Out:
#                                                 title             author  \
# 0   Atomic Habits: the life-changing million-copy ...        James Clear
# 1   The Hidden Hindu (Hindi Translation of The Hid...       Akshat Gupta
# 2   Ikigai: The Japanese secret to a long and happ...  Francesc Miralles
# 3                             The Psychology of Money      Morgan Housel
# 4   The Hidden Hindu: Science-Fiction meets Indian...       Akshat Gupta
# ..                                                ...                ...
# 95  Concept of Physics by H.C Verma Part - II - Se...         H.C. Verma
# 96  Interact in English Main Course Book (MCB) + L...                NaN
# 97  R D Sharma Mathematics Class 10 with MCQ in Ma...        R.D. Sharma
# 98                                             Verity     Colleen Hoover
# 99  BRAIN GAMES FOR CLEVER KIDS [Paperback] Moore,...                NaN
#
#                 rating       reviews   price  \
# 0   4.6 out of 5 stars         78722  396.00
# 1   4.5 out of 5 stars           302  150.00
# 2   4.6 out of 5 stars         48160  374.00
# 3   4.6 out of 5 stars         50257  200.00
# 4   4.4 out of 5 stars          1535  180.00
# ..                 ...           ...     ...
# 95  4.6 out of 5 stars         10085  330.00
# 96  4.4 out of 5 stars       EXAM360  324.00
# 97  4.5 out of 5 stars          2530  450.00
# 98  4.3 out of 5 stars        226395  235.00
# 99  4.3 out of 5 stars  Gareth Moore  139.00
#
#                                             book_link                 date
# 0   https://www.amazon.in/Atomic-Habits-James-Clea...  2023-06-12 11:05:09
# 1   https://www.amazon.in/Hidden-Hindu-Hindi-Trans...  2023-06-12 11:05:09
# 2   https://www.amazon.in/Ikigai-H%C3%A9ctor-Garc%...  2023-06-12 11:05:09
# 3   https://www.amazon.in/Psychology-Money-Morgan-...  2023-06-12 11:05:09
# 4   https://www.amazon.in/Hidden-Hindu-Akshat-Gupt...  2023-06-12 11:05:09
# ..                                                ...                  ...
# 95  https://www.amazon.in/Concept-Physics-Part-2-2...  2023-06-12 11:05:15
# 96  https://www.amazon.in/Interact-English-Course-...  2023-06-12 11:05:15
# 97  https://www.amazon.in/Mathematics-Class-10-Exa...  2023-06-12 11:05:15
# 98  https://www.amazon.in/Verity-thriller-that-cap...  2023-06-12 11:05:15
# 99  https://www.amazon.in/Brain-Games-Clever-Kids-...  2023-06-12 11:05:15
#
# [100 rows x 7 columns]

# %%
best_sellers_books_all.to_csv('amazon_best_sellers.csv', index=False)
